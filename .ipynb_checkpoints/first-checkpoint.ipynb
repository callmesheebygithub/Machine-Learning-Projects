# %%
# personal token
# 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

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('Churn_Modelling.csv')
df.sample(7)
# Out:
#       RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 2841       2842    15748473    Curnow          801    France    Male   38
# 3475       3476    15770554    Fraser          769    France    Male   31
# 8671       8672    15689526      Shih          542   Germany  Female   35
# 111         112    15665790  Rowntree          538   Germany    Male   39
# 9550       9551    15721715      Fane          769    France  Female   40
# 1499       1500    15583595       Tao          461    France  Female   28
# 5869       5870    15734461    Brooks          562   Germany    Male   31
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 2841       5       0.00              2          1               0
# 3475       4   61297.05              2          1               1
# 8671       9  127543.11              2          1               0
# 111        7  108055.10              2          1               0
# ...

# %%
sns.scatterplot(df['NumOfProducts'],df['Age'],hue=df['HasCrCard'],style=df['IsActiveMember'],size=df['Gender'])
plt.show()
# Out:
# C:\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df.duplicated().any()
# Out:
# False

# %%
df.shape
# Out:
# (10000, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %%
df.isnull().mean()
# Out:
# RowNumber          0.0
# CustomerId         0.0
# Surname            0.0
# CreditScore        0.0
# Geography          0.0
# Gender             0.0
# Age                0.0
# Tenure             0.0
# Balance            0.0
# NumOfProducts      0.0
# HasCrCard          0.0
# IsActiveMember     0.0
# EstimatedSalary    0.0
# Exited             0.0
# dtype: float64

# %%
df['Geography'].value_counts()
# Out:
# France     5014
# Germany    2509
# Spain      2477
# Name: Geography, dtype: int64

# %%
df.describe().round(2)
# Out:
#        RowNumber   CustomerId  CreditScore       Age    Tenure    Balance  \
# count   10000.00     10000.00     10000.00  10000.00  10000.00   10000.00
# mean     5000.50  15690940.57       650.53     38.92      5.01   76485.89
# std      2886.90     71936.19        96.65     10.49      2.89   62397.41
# min         1.00  15565701.00       350.00     18.00      0.00       0.00
# 25%      2500.75  15628528.25       584.00     32.00      3.00       0.00
# 50%      5000.50  15690738.00       652.00     37.00      5.00   97198.54
# 75%      7500.25  15753233.75       718.00     44.00      7.00  127644.24
# max     10000.00  15815690.00       850.00     92.00     10.00  250898.09
#
#        NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary   Exited
# count       10000.00   10000.00        10000.00         10000.00  10000.0
# mean            1.53       0.71            0.52        100090.24      0.2
# std             0.58       0.46            0.50         57510.49      0.4
# ...

# %%
plt.hist(df['Age'], bins=30, color='y')
plt.show()

# %%
sns.distplot(df['Age'], color='g')
plt.show()
# Out:
# C:\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
df=df[df['Age']<60].dropna()

# %%
sns.boxplot(df['CreditScore'],df['Gender'])
plt.show()
# Out:
# C:\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.boxplot(df['EstimatedSalary'],df['Gender'])
plt.show()
# Out:
# C:\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.boxplot(df['Age'], df['Gender'])
plt.show()
# Out:
# C:\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
data=df[df['Age']>66]

# %%
sns.histplot(da['Age'])
plt.show()

# %%
len(da)
# Out:
# 235

# %%
data=df[df['Age']<60].dropna()
data.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
data.sample(10)
# Out:
#       RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 4348       4349    15579387        Ni          635   Germany  Female   44
# 1666       1667    15579706    Curtis          611    France  Female   46
# 4645       4646    15782144    Gilroy          522    France  Female   34
# 5703       5704    15621063   Gibbons          516    France  Female   42
# 1648       1649    15655574     Okeke          698   Germany  Female   40
# 2559       2560    15650670   Bateson          567   Germany  Female   40
# 5128       5129    15726250      Hsia          508    France  Female   38
# 1712       1713    15744983  Burgmann          712     Spain    Male   47
# 1385       1386    15672756     Mills          716    France  Female   35
# 6108       6109    15761076       Lei          507    France    Male   41
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 4348       2   79064.85              2          0               1
# ...

# %%
da=data[data['Age']>60]

# %%
da
# Out:
# Empty DataFrame
# Columns: [RowNumber, CustomerId, Surname, CreditScore, Geography, Gender, Age, Tenure, Balance, NumOfProducts, HasCrCard, IsActiveMember, EstimatedSalary, Exited]
# Index: []

# %%
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
colors=['darkgreen','orange','darkblue']
explode = [0.1, 0.0, 0.2, 0.3, 0.0, 0.0]
df['Geography'].value_counts().plot(kind='pie',autopct='%.2f',colors=colors)
plt.show()

# %%
sns.scatterplot(df['Balance'],df['EstimatedSalary'],hue=df['Gender'],size=df['Age'])
plt.show()
# Out:
# C:\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.boxplot(df['EstimatedSalary'],hue=df['Gender'])
plt.show()
# Out:
# C:\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
# sns.barplot(df['EstimatedSalary'],df['Age'])
# plt.show()

# %%
df.sample(4)
# Out:
#       RowNumber  CustomerId     Surname  CreditScore Geography  Gender  Age  \
# 4370       4371    15740470  Vinogradov          725    France    Male   39
# 7394       7395    15673747       Ayers          519    France  Female   22
# 9790       9791    15658211    Morrison          559     Spain  Female   39
# 1541       1542    15812497  D'Albertis          654   Germany    Male   37
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 4370       4  160652.45              2          1               0
# 7394       8       0.00              1          0               1
# 9790       2       0.00              2          1               1
# 1541       5  112146.12              1          1               0
#
#       EstimatedSalary  Exited
# 4370         57643.55       0
# 7394        167553.06       0
# 9790        121151.10       0
# 1541         75927.35       0

# %%
df=df.drop(['RowNumber','Tenure','NumOfProducts','HasCrCard','IsActiveMember','Exited'],axis=1)

# %%
df.sample(5)
# Out:
#       CustomerId  Surname  CreditScore Geography  Gender  Age   Balance  \
# 1120    15589358  Stanley          848   Germany    Male   31  90018.45
# 6324    15746012  Chibugo          729     Spain  Female   28      0.00
# 2096    15757916  Amaechi          600    France  Female   38      0.00
# 2728    15770420   Dillon          749   Germany    Male   46  78136.36
# 2002    15657214     Hsia          601    France    Male   74      0.00
#
#       EstimatedSalary
# 1120        193132.98
# 6324         31165.06
# 2096         58855.85
# 2728         73470.98
# 2002         51554.58

# %%
hig=df.groupby('Gender')['EstimatedSalary'].max()
hig
# Out:
# Gender
# Female    199992.48
# Male      199953.33
# Name: EstimatedSalary, dtype: float64

# %%
ddf.groupby('Gender')['Balance'].max()
# Out:
# Gender
# Female    238387.56
# Male      250898.09
# Name: Balance, dtype: float64

# %%
name=df[df['EstimatedSalary']==199992.48]['Surname']
name
# Out:
# 6646    Lucciano
# Name: Surname, dtype: object

# %%
df[df['Balance']==238387.56]['Surname']
# Out:
# 3280    To Rot
# Name: Surname, dtype: object

# %%
df.sample(5)
# Out:
#       CustomerId    Surname  CreditScore Geography  Gender  Age    Balance  \
# 8259    15703199     Golibe          619     Spain    Male   38   96143.47
# 8235    15760177   Lombardi          564     Spain    Male   37  100252.18
# 3139    15736228   Chambers          645    France  Female   40  129596.77
# 5658    15814430         Ma          747     Spain    Male   41       0.00
# 1557    15706815  Samoylova          515   Germany    Male   37   90432.92
#
#       EstimatedSalary
# 8259         98994.92
# 8235        146033.52
# 3139        103232.60
# 5658         32430.94
# 1557        188366.04

# %%
new=df[df['Age'].between(60,100)]

# %%
sns.boxplot(new['Age'],new['Gender'])
plt.show()
# Out:
# C:\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
